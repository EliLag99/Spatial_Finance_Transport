# %%
import json
import pandas as pd
import urllib

# %%
# READ THE EMISSIONS DATASET
#  KEEP ONE ROW ONLY PER LA FOR EASIER DATA PROCESSING

df_emissions=pd.read_csv("./uk-local-authority-ghg-emissions-2020-dataset.csv")
df_emissions = df_emissions.drop_duplicates(subset=["Local Authority"], keep="last")#[["Local Authority Code", "Region", "Local Authority", "Area (km2)", "Mid-year Population (thousands)", "Calendar Year"]];
df_emissions.drop(df_emissions[df_emissions["Region"]=="London"].index, inplace=True);
df_emissions = df_emissions.sort_values(["Local Authority Code", "Calendar Year", "Area (km2)"])
df_emissions
# Out:
#         Country Country Code      Region Region Code Second Tier Authority  \
# 143981  England    E92000001  North East   E12000001            Hartlepool
# 145182  England    E92000001  North East   E12000001         Middlesbrough
# 150230  England    E92000001  North East   E12000001  Redcar and Cleveland
# 152689  England    E92000001  North East   E12000001      Stockton-on-Tees
# 140186  England    E92000001  North East   E12000001            Darlington
# ...         ...          ...         ...         ...                   ...
# 464874    Wales    W92000004       Wales   W92000004                 Wales
# 455912    Wales    W92000004       Wales   W92000004                 Wales
# 458468    Wales    W92000004       Wales   W92000004                 Wales
# 461014    Wales    W92000004       Wales   W92000004                 Wales
# 454604    Wales    W92000004       Wales   W92000004                 Wales
#
#              Local Authority Local Authority Code  Calendar Year  \
# 143981            Hartlepool            E06000001           2020
# 145182         Middlesbrough            E06000002           2020
# 150230  Redcar and Cleveland            E06000003           2020
# 152689      Stockton-on-Tees            E06000004           2020
# 140186            Darlington            E06000005           2020
# ...                      ...                  ...            ...
# 464874               Torfaen            W06000020           2020
# 455912         Monmouthshire            W06000021           2020
# 458468               Newport            W06000022           2020
# 461014                 Powys            W06000023           2020
# 454604        Merthyr Tydfil            W06000024           2020
#
#            LA GHG Sector         LA GHG Sub-sector Greenhouse gas  \
# 143981  Waste management  Waste management 'Other'            N2O
# 145182  Waste management  Waste management 'Other'            N2O
# 150230  Waste management  Waste management 'Other'            N2O
# 152689  Waste management  Waste management 'Other'            N2O
# 140186  Waste management  Waste management 'Other'            N2O
# ...                  ...                       ...            ...
# 464874  Waste management  Waste management 'Other'            N2O
# 455912  Waste management  Waste management 'Other'            N2O
# 458468  Waste management  Waste management 'Other'            N2O
# 461014  Waste management  Waste management 'Other'            N2O
# 454604  Waste management  Waste management 'Other'            N2O
#
#         Territorial emissions (kt CO2e)  \
# 143981                         1.951778
# 145182                         1.980158
# 150230                         2.076715
# 152689                        10.555841
# 140186                         1.737039
# ...                                 ...
# 464874                         1.530829
# 455912                         1.732467
# 458468                         2.528651
# 461014                         2.373984
# 454604                         0.929734
#
#         CO2 emissions within the scope of influence of LAs (kt CO2e)  \
# 143981                                                0.0
# 145182                                                0.0
# 150230                                                0.0
# 152689                                                0.0
# 140186                                                0.0
# ...                                                   ...
# 464874                                                0.0
# 455912                                                0.0
# 458468                                                0.0
# 461014                                                0.0
# 454604                                                0.0
#
#         Mid-year Population (thousands)  Area (km2)
# 143981                           93.836     98.3466
# 145182                          141.285     54.5537
# 150230                          137.228    253.7857
# 152689                          197.419    209.7309
# 140186                          107.402    197.4758
# ...                                 ...         ...
# 464874                           94.832    126.2401
# 455912                           95.164    886.0557
# 458468                          156.447    217.4554
# 461014                          133.030   5195.4561
# 454604                           60.424    111.9569
#
# [344 rows x 15 columns]

# %%
# READ ROAD LENGTHS DATASET

df_roads = pd.read_csv("./rdl0202.csv", skiprows=6)
df_roads = df_roads[["ONS Area \nCode", "Region", "Local Authority", "All 'A' roads", "Total road length "]]
df_roads.drop(df_roads[df_roads["Region"]=="London"].index, inplace=True);
df_roads=df_roads.sort_values(["ONS Area \nCode"])
df_roads
# Out:
#     ONS Area \nCode      Region          Local Authority All 'A' roads  \
# 2         E06000001  North East            Hartlepool UA          48.0
# 3         E06000002  North East         Middlesbrough UA          48.4
# 5         E06000003  North East  Redcar and Cleveland UA          95.4
# 6         E06000004  North East      Stockton-on-Tees UA         104.1
# 1         E06000005  North East            Darlington UA          65.0
# ..              ...         ...                      ...           ...
# 171       W06000020       Wales                  Torfaen          36.5
# 172       W06000021       Wales            Monmouthshire         154.2
# 173       W06000022       Wales                  Newport          57.9
# 158       W06000023       Wales                    Powys         664.4
# 168       W06000024       Wales           Merthyr Tydfil          59.1
#
#     Total road length
# 2                413.6
# 3                540.5
# 5                689.4
# 6                900.3
# 1                563.2
# ..                 ...
# 171              482.1
# 172            1,627.6
# 173              759.4
# 158            5,344.9
# 168              347.7
#
# [173 rows x 5 columns]

# %%
merged_df = pd.merge(df_emissions[["Local Authority Code", "Local Authority", "Region", "Area (km2)"]], df_roads[["ONS Area \nCode","Local Authority", "All 'A' roads", "Total road length "]], left_on="Local Authority Code", right_on="ONS Area \nCode", how="inner")
merged_df = merged_df.sort_values(["Area (km2)", "Local Authority Code"])
merged_df
# Out:
#     Local Authority Code      Local Authority_x           Region  Area (km2)  \
# 49             E06000053        Isles of Scilly       South West     22.8495
# 36             E06000039                 Slough       South East     32.5419
# 35             E06000038                Reading       South East     40.3979
# 8              E06000009              Blackpool       North West     43.1508
# 29             E06000032                  Luton  East of England     43.3525
# ..                   ...                    ...              ...         ...
# 124            S12000048      Perth and Kinross         Scotland   5418.9445
# 114            S12000034          Aberdeenshire         Scotland   6338.1488
# 96             S12000006  Dumfries and Galloway         Scotland   6676.3147
# 115            S12000035        Argyll and Bute         Scotland   7165.1715
# 102            S12000017               Highland         Scotland  26473.9496
#
#     ONS Area \nCode      Local Authority_y All 'A' roads Total road length
# 49        E06000053     Isles of Scilly UA           7.8               34.2
# 36        E06000039              Slough UA          22.7              323.1
# 35        E06000038             Reading UA          36.9              397.7
# 8         E06000009           Blackpool UA          41.8              458.0
# 29        E06000032               Luton UA          34.6              467.0
# ..              ...                    ...           ...                ...
# 124       S12000048      Perth and Kinross         622.1            2,902.8
# 114       S12000034          Aberdeenshire         909.8            6,257.1
# 96        S12000006  Dumfries and Galloway         784.4            4,654.6
# 115       S12000035          Argyll & Bute         796.6            2,695.1
# 102       S12000017               Highland       2,353.2            7,988.2
#
# [149 rows x 8 columns]

# %%
with open("la_countsite_dict.json") as dictionary_json:
    la_countsites=json.load(dictionary_json)

# %%
from tqdm import tqdm

START_DATE = "01012017"
END_DATE = "01012020"

for key, value in tqdm(la_countsites.items()):
    for site in value:
        site_id = site["Id"]
        url_text = f"https://webtris.highwaysengland.co.uk/api/v1/quality/overall?sites={site_id}&start_date={START_DATE}&end_date={END_DATE}"
        with urllib.request.urlopen(url_text) as url:
            site_report = json.loads(url.read().decode())
        site["Quality"] = site_report["data_quality"]
# Out:
# 100%|██████████| 361/361 [08:23<00:00,  1.39s/it]

# %%
THRESHOLD = 90

la_quality_countsites = {}
for la, sites in la_countsites.items():
    la_quality_countsites[la] = list(filter(lambda site: site["Quality"] >= THRESHOLD, sites))

la_quality_countsites
# Out:
# {'E06000001': [{'Id': '8399',
#    'Name': 'TMU Site 9359/1 on link A19 southbound between A179 and A689; GPS Ref: 445205;528224; Southbound',
#    'Description': '9359/1',
#    'Longitude': -1.30100633733483,
#    'Latitude': 54.6471162774851,
#    'Status': 'Active',
#    'Quality': 93}],
#  'E06000002': [{'Id': '8717',
#    'Name': 'TMU Site 9317/2 on link A66 westbound within the A19 junction after A19 southbound access; GPS Ref: 447210;518843; Westbound',
#    'Description': '9317/2',
#    'Longitude': -1.27144368615249,
#    'Latitude': 54.5626367095158,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8718',
#    'Name': 'TMU Site 9321/3 on link A66 westbound within the A19 junction before A19 southbound access; GPS Ref: 447656;518896; Westbound',
#    'Description': '9321/3',
#    'Longitude': -1.26453864814253,
#    'Latitude': 54.5630713063465,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8394',
#    'Name': 'TMU Site 9323/1 on link A19 northbound exit for A66; GPS Ref: 447366;518608; Northbound',
#    'Description': '9323/1',
#    'Longitude': -1.26906915299207,
#    'Latitude': 54.5605104788539,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8393',
#    'Name': 'TMU Site 9323/2 on link A19 northbound within the A66 junction; GPS Ref: 447382;518605; Northbound',
#    'Description': '9323/2',
#    'Longitude': -1.2688222395529,
#    'Latitude': 54.5604820284073,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8392',
#    'Name': 'TMU Site 9324/1 on link A19 southbound access from A66; GPS Ref: 447397;518555; Southbound',
#    'Description': '9324/1',
#    'Longitude': -1.26859833137258,
#    'Latitude': 54.5600313299436,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8391',
#    'Name': 'TMU Site 9324/2 on link A19 southbound within the A66 junction after A66 westbound exit; GPS Ref: 447382;518561; Southbound',
#    'Description': '9324/2',
#    'Longitude': -1.26882929862423,
#    'Latitude': 54.5600866454728,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8390',
#    'Name': 'TMU Site 9325/1 on link A19 southbound exit for A1130; GPS Ref: 447111;517469; Southbound',
#    'Description': '9325/1',
#    'Longitude': -1.2731937730038,
#    'Latitude': 54.5502990210954,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8389',
#    'Name': 'TMU Site 9325/2 on link A19 southbound within the A1130 junction; GPS Ref: 447093;517477; Southbound',
#    'Description': '9325/2',
#    'Longitude': -1.27347074502585,
#    'Latitude': 54.5503725807096,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8388',
#    'Name': 'TMU Site 9326/1 on link A19 northbound exit for A1130; GPS Ref: 446922;517107; Northbound',
#    'Description': '9326/1',
#    'Longitude': -1.27617296322618,
#    'Latitude': 54.5470634839653,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8387',
#    'Name': 'TMU Site 9326/2 on link A19 northbound within the A1130 junction; GPS Ref: 446942;517101; Northbound',
#    'Description': '9326/2',
#    'Longitude': -1.27586477675076,
#    'Latitude': 54.5470077178143,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8386',
#    'Name': 'TMU Site 9327/1 on link A19 southbound exit for A174; GPS Ref: 446726;515454; Southbound',
#    'Description': '9327/1',
#    'Longitude': -1.27946449633629,
#    'Latitude': 54.5322268895812,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8385',
#    'Name': 'TMU Site 9327/2 on link A19 southbound within the A174 junction; GPS Ref: 446704;515452; Southbound',
#    'Description': '9327/2',
#    'Longitude': -1.27980474498337,
#    'Latitude': 54.5322109394611,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8384',
#    'Name': 'TMU Site 9328/1 on link A19 northbound exit for A174; GPS Ref: 446643;514816; Northbound',
#    'Description': '9328/1',
#    'Longitude': -1.28084781290373,
#    'Latitude': 54.5265011201046,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8383',
#    'Name': 'TMU Site 9328/2 on link A19 northbound within the A174 junction; GPS Ref: 446667;514818; Northbound',
#    'Description': '9328/2',
#    'Longitude': -1.28047671330179,
#    'Latitude': 54.5265168898576,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8368',
#    'Name': 'TMU Site 9329/1 on link A174 eastbound between A19 and A1044; GPS Ref: 447235;515054; Eastbound',
#    'Description': '9329/1',
#    'Longitude': -1.27166373010981,
#    'Latitude': 54.528585207424904,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '9132',
#    'Name': 'TMU Site 9330/1 on link A174 westbound access from A1044; GPS Ref: 447936;514911; Westbound',
#    'Description': '9330/1',
#    'Longitude': -1.26085622502158,
#    'Latitude': 54.5272344611798,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '9131',
#    'Name': 'TMU Site 9330/2 on link A174 westbound between A1032 and A1044; GPS Ref: 447937;514936; Westbound',
#    'Description': '9330/2',
#    'Longitude': -1.26083672242164,
#    'Latitude': 54.5274590218797,
#    'Status': 'Active',
#    'Quality': 93}],
#  'E06000003': [{'Id': '8370',
#    'Name': 'TMU Site 9332/1 on link A174 westbound between A1053 and A171; GPS Ref: 455603;517872; Westbound',
#    'Description': '9332/1',
#    'Longitude': -1.14184764365872,
#    'Latitude': 54.5530608622854,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8365',
#    'Name': 'TMU Site 9333/1 on link A1053 northbound between A174 and A1085; GPS Ref: 455914;520337; Northbound',
#    'Description': '9333/1',
#    'Longitude': -1.13657236512372,
#    'Latitude': 54.5751768549971,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8364',
#    'Name': 'TMU Site 9334/1 on link A1053 southbound at a minor junction between A1085 and A174; GPS Ref: 456153;520038; Southbound',
#    'Description': '9334/1',
#    'Longitude': -1.13293266615685,
#    'Latitude': 54.5724636668749,
#    'Status': 'Active',
#    'Quality': 93}],
#  'E06000004': [{'Id': '8713',
#    'Name': 'TMU Site 9312/1 on link A66 eastbound between A1150 and A135; GPS Ref: 436239;516395; Eastbound',
#    'Description': '9312/1',
#    'Longitude': -1.44139302072428,
#    'Latitude': 54.5415388396611,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8712',
#    'Name': 'TMU Site 9313/1 on link A66 westbound between A135 and A1150; GPS Ref: 436564;516300; Westbound',
#    'Description': '9313/1',
#    'Longitude': -1.43638175321666,
#    'Latitude': 54.5406618708581,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '9130',
#    'Name': 'TMU Site 9314/1 on link A66 eastbound access from A135; GPS Ref: 443423;517077; Eastbound',
#    'Description': '9314/1',
#    'Longitude': -1.33026217261247,
#    'Latitude': 54.5471050454717,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9129',
#    'Name': 'TMU Site 9314/2 on link A66 eastbound within the A135 junction; GPS Ref: 443427;517061; Eastbound',
#    'Description': '9314/2',
#    'Longitude': -1.33020269585515,
#    'Latitude': 54.5469609242877,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8714',
#    'Name': 'TMU Site 9315/1 on link A66 westbound between A135 near Stockton (east) and A135 near Stockton (west); GPS Ref: 444193;517779; Westbound',
#    'Description': '9315/1',
#    'Longitude': -1.31825505980527,
#    'Latitude': 54.5533469931097,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8382',
#    'Name': 'TMU Site 9335/1 on link A19 southbound between A174 and A67; GPS Ref: 446083;512558; Southbound',
#    'Description': '9335/1',
#    'Longitude': -1.28985139408581,
#    'Latitude': 54.506261239191,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8397',
#    'Name': 'TMU Site 9360/1 on link A19 northbound between A1027 and A689; GPS Ref: 444227;523650; Northbound',
#    'Description': '9360/1',
#    'Longitude': -1.31684931580249,
#    'Latitude': 54.6061010952667,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8396',
#    'Name': 'TMU Site 9361/1 on link A19 southbound between A689 and A1027; GPS Ref: 444238;525128; Southbound',
#    'Description': '9361/1',
#    'Longitude': -1.31645695530627,
#    'Latitude': 54.6193814204787,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '9226',
#    'Name': 'TMU Site 9483/1 on link A19 southbound access from A1046; GPS Ref: 447120;520393; Southbound',
#    'Description': '9483/1',
#    'Longitude': -1.27258791419017,
#    'Latitude': 54.5765733212599,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9227',
#    'Name': 'TMU Site 9484/1 on link A19 southbound within the A1046 junction; GPS Ref: 446614;520590; Southbound',
#    'Description': '9484/1',
#    'Longitude': -1.28038374664768,
#    'Latitude': 54.5783902752351,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E06000005': [{'Id': '8678',
#    'Name': 'TMU Site 9291/1 on link A1(M) southbound between J58 and J57; GPS Ref: 425953;517221; Southbound',
#    'Description': '9291/1',
#    'Longitude': -1.60030001358802,
#    'Latitude': 54.5495904026029,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8332',
#    'Name': 'TMU Site 9293/1 on link A1(M) J58 southbound exit; GPS Ref: 426453;518098; Southbound',
#    'Description': '9293/1',
#    'Longitude': -1.59249181858199,
#    'Latitude': 54.5574457410587,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8331',
#    'Name': 'TMU Site 9293/2 on link A1(M) southbound within J58; GPS Ref: 426436;518108; Southbound',
#    'Description': '9293/2',
#    'Longitude': -1.59275377937537,
#    'Latitude': 54.5575364881881,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8708',
#    'Name': 'TMU Site 9310/1 on link A66 westbound between A67 near Darlington (east) and A67 near Darlington (south); GPS Ref: 430022;512391; Westbound',
#    'Description': '9310/1',
#    'Longitude': -1.53788732454125,
#    'Latitude': 54.5059617983981,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8709',
#    'Name': 'TMU Site 9310/2 on link A66 eastbound between A67 near Darlington (south) and A67 near Darlington (east); GPS Ref: 430021;512396; Eastbound',
#    'Description': '9310/2',
#    'Longitude': -1.53790226009293,
#    'Latitude': 54.5060067903154,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8711',
#    'Name': 'TMU Site 9311/1 on link A66 westbound between A1150 and A67 near Darlington (east); GPS Ref: 432687;515016; Westbound',
#    'Description': '9311/1',
#    'Longitude': -1.49644373738963,
#    'Latitude': 54.5293873349751,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8710',
#    'Name': 'TMU Site 9311/2 on link A66 eastbound between A67 near Darlington (east) and B6279; GPS Ref: 432682;515016; Eastbound',
#    'Description': '9311/2',
#    'Longitude': -1.4965209925266,
#    'Latitude': 54.5293876561189,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E06000006': [],
#  'E06000007': [],
#  'E06000008': [],
#  'E06000009': [],
#  'E06000010': [{'Id': '9370',
#    'Name': 'TMU Site 7070/1 on A63 westbound exit for A1033 North; GPS Ref: 511782;429197; Westbound',
#    'Description': '7070/1',
#    'Longitude': -0.306410701221611,
#    'Latitude': 53.7471898975446,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9371',
#    'Name': 'TMU Site 7070/2 on A63 westbound between A1033 and A1165; GPS Ref: 511777;429210; Westbound',
#    'Description': '7070/2',
#    'Longitude': -0.306481786844649,
#    'Latitude': 53.7473077613351,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '9372',
#    'Name': 'TMU Site 7071/1 on A63 eastbound exit for A1033 North; GPS Ref: 511216;429009; Eastbound',
#    'Description': '7071/1',
#    'Longitude': -0.315057027871688,
#    'Latitude': 53.7456217373454,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9373',
#    'Name': 'TMU Site 7071/2 on A63 eastbound between A1165 and A1033 South; GPS Ref: 511158;428954; Eastbound',
#    'Description': '7071/2',
#    'Longitude': -0.315955853931674,
#    'Latitude': 53.7451399556961,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8573',
#    'Name': 'TMU Site 8810/1 on A63 eastbound exit for A1166; GPS Ref: 507147;426934; Eastbound',
#    'Description': '8810/1',
#    'Longitude': -0.377447550917463,
#    'Latitude': 53.7278298384161,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8572',
#    'Name': 'TMU Site 8810/2 on A63 eastbound within the A1166 junction; GPS Ref: 507154;426921; Eastbound',
#    'Description': '8810/2',
#    'Longitude': -0.377345996748734,
#    'Latitude': 53.7277116052766,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8569',
#    'Name': 'TMU Site 8855/1 on A63 westbound exit at a minor junction between A1166 and A15/A1105; GPS Ref: 504621;426067; Westbound',
#    'Description': '8855/1',
#    'Longitude': -0.416009719717739,
#    'Latitude': 53.7205506035417,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8568',
#    'Name': 'TMU Site 8855/2 on A63 westbound at a minor junction between A1166 and A15/A1105; GPS Ref: 504619;426081; Westbound',
#    'Description': '8855/2',
#    'Longitude': -0.416035296714367,
#    'Latitude': 53.7206767957254,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8579',
#    'Name': 'TMU Site 8858/1 on A63 westbound exit at a minor junction between A1079 and A1166; GPS Ref: 508677;428043; Westbound',
#    'Description': '8858/1',
#    'Longitude': -0.353878535573485,
#    'Latitude': 53.7374774888442,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8578',
#    'Name': 'TMU Site 8858/2 on A63 westbound at a minor junction between A1079 and A1166; GPS Ref: 508673;428050; Westbound',
#    'Description': '8858/2',
#    'Longitude': -0.353936691735208,
#    'Latitude': 53.7375412119431,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9003',
#    'Name': 'TMU Site 8877/1 on A63 eastbound between A1166 and A1079; GPS Ref: 509022;428213; Eastbound',
#    'Description': '8877/1',
#    'Longitude': -0.348590674987505,
#    'Latitude': 53.7389329397743,
#    'Status': 'Active',
#    'Quality': 97}],
#  'E06000011': [{'Id': '8586',
#    'Name': 'TMU Site 8793/1 on link A63 westbound between A1034 and M62/B1230; GPS Ref: 491956;430373; Westbound',
#    'Description': '8793/1',
#    'Longitude': -0.606595426774649,
#    'Latitude': 53.7616262423473,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8585',
#    'Name': 'TMU Site 8794/1 on link A63 eastbound exit for A1034; GPS Ref: 492368;430406; Eastbound',
#    'Description': '8794/1',
#    'Longitude': -0.600337853300694,
#    'Latitude': 53.761849988331,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8584',
#    'Name': 'TMU Site 8794/2 on link A63 eastbound within the A1034 junction; GPS Ref: 492368;430391; Eastbound',
#    'Description': '8794/2',
#    'Longitude': -0.600342335066724,
#    'Latitude': 53.7617152082837,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8583',
#    'Name': 'TMU Site 8795/1 on link A63 westbound exit for A1034; GPS Ref: 492816;430241; Westbound',
#    'Description': '8795/1',
#    'Longitude': -0.59359374173087,
#    'Latitude': 53.760287914878504,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8582',
#    'Name': 'TMU Site 8795/2 on link A63 westbound within the A1034 junction; GPS Ref: 492817;430247; Westbound',
#    'Description': '8795/2',
#    'Longitude': -0.593576776637579,
#    'Latitude': 53.7603416488608,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8571',
#    'Name': 'TMU Site 8796/1 on link A63 eastbound exit for A15/A1105; GPS Ref: 501017;426111; Eastbound',
#    'Description': '8796/1',
#    'Longitude': -0.470590061682533,
#    'Latitude': 53.7216550504565,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8570',
#    'Name': 'TMU Site 8796/2 on link A63 eastbound within the A15/A1105 junction; GPS Ref: 501011;426096; Eastbound',
#    'Description': '8796/2',
#    'Longitude': -0.470685846392068,
#    'Latitude': 53.7215214364599,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8567',
#    'Name': 'TMU Site 8797/1 on link A63 westbound exit for A15/A1105; GPS Ref: 501122;426007; Westbound',
#    'Description': '8797/1',
#    'Longitude': -0.46903336924205,
#    'Latitude': 53.7207002742836,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8566',
#    'Name': 'TMU Site 8797/2 on link A63 westbound within the A15/A1105 junction; GPS Ref: 501127;426020; Westbound',
#    'Description': '8797/2',
#    'Longitude': -0.468953382738808,
#    'Latitude': 53.7208161106824,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '8565',
#    'Name': 'TMU Site 8854/1 on A63 eastbound exit at a minor junction between A15/A1105 and A1166; GPS Ref: 504153;426005; Eastbound',
#    'Description': '8854/1',
#    'Longitude': -0.423119449931076,
#    'Latitude': 53.720086390956,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8564',
#    'Name': 'TMU Site 8854/2 on A63 eastbound at a minor junction between A15/A1105 and A1166; GPS Ref: 504156;425996; Eastbound',
#    'Description': '8854/2',
#    'Longitude': -0.423077035732804,
#    'Latitude': 53.7200049327575,
#    'Status': 'Active',
#    'Quality': 93}],
#  'E06000012': [{'Id': '8563',
#    'Name': 'TMU Site 8849/1 on link A180 eastbound between A160 and A1173; GPS Ref: 514362;414308; Eastbound',
#    'Description': '8849/1',
#    'Longitude': -0.272787113300782,
#    'Latitude': 53.6128688081777,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8562',
#    'Name': 'TMU Site 8850/1 on link A180 westbound between A1173 and A160; GPS Ref: 514359;414295; Westbound',
#    'Description': '8850/1',
#    'Longitude': -0.272837202555766,
#    'Latitude': 53.612752668637,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8561',
#    'Name': 'TMU Site 8851/1 on link A180 eastbound between A1173 and A1136; GPS Ref: 520475;412528; Eastbound',
#    'Description': '8851/1',
#    'Longitude': -0.181120012941785,
#    'Latitude': 53.5955098429323,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8560',
#    'Name': 'TMU Site 8852/1 on link A180 westbound between A1136 and A1173; GPS Ref: 520440;412522; Westbound',
#    'Description': '8852/1',
#    'Longitude': -0.181650877039208,
#    'Latitude': 53.5954639694828,
#    'Status': 'Active',
#    'Quality': 97}],
#  'E06000013': [],
#  'E06000014': [{'Id': '8694',
#    'Name': 'TMU Site 9256/1 on link A64 westbound between A19 and A1036; GPS Ref: 459176;448343; Westbound',
#    'Description': '9256/1',
#    'Longitude': -1.10029940836442,
#    'Latitude': 53.9278629807016,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8697',
#    'Name': 'TMU Site 9258/1 on link A64 westbound between A166/A1079 and A19; GPS Ref: 462269;448140; Westbound',
#    'Description': '9258/1',
#    'Longitude': -1.05324451079318,
#    'Latitude': 53.9256769063646,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8698',
#    'Name': 'TMU Site 9259/1 on link A64 northbound between A166/A1079 and A1237 near York (north); GPS Ref: 464353;453240; Northbound',
#    'Description': '9259/1',
#    'Longitude': -1.0204417325051,
#    'Latitude': 53.9712530182922,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8699',
#    'Name': 'TMU Site 9260/1 on link A64 westbound between A1237 near York (north) and A166/A1079; GPS Ref: 464396;453679; Westbound',
#    'Description': '9260/1',
#    'Longitude': -1.01969380949055,
#    'Latitude': 53.9751926311127,
#    'Status': 'Active',
#    'Quality': 97}],
#  'E06000015': [{'Id': '10691',
#    'Name': 'TMU Site 7163/1 on A6 northbound between B5010 and A5111; GPS Ref: 439755;333032; Northbound',
#    'Description': '7163/1',
#    'Longitude': -1.41052853636689,
#    'Latitude': 52.8932924596907,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8488',
#    'Name': 'TMU Site 8261/1 on link A50 eastbound exit for A514; GPS Ref: 437558;329488; Eastbound',
#    'Description': '8261/1',
#    'Longitude': -1.44358973298994,
#    'Latitude': 52.8615928345953,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8487',
#    'Name': 'TMU Site 8261/2 on link A50 eastbound within the A514 junction; GPS Ref: 437551;329467; Eastbound',
#    'Description': '8261/2',
#    'Longitude': -1.44369610662085,
#    'Latitude': 52.8614045504552,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8498',
#    'Name': 'TMU Site 8276/1 on link A5111 southbound between A52 and A6 near Derby (north); GPS Ref: 438392;334375; Southbound',
#    'Description': '8276/1',
#    'Longitude': -1.43062904432655,
#    'Latitude': 52.9054632679486,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '8468',
#    'Name': 'TMU Site 8285/1 on link A38 northbound between A5111 and A52; GPS Ref: 433063;336651; Northbound',
#    'Description': '8285/1',
#    'Longitude': -1.50962662251779,
#    'Latitude': 52.9262746683369,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8467',
#    'Name': 'TMU Site 8286/1 on link A38 southbound between A52 and A5111; GPS Ref: 433187;336763; Southbound',
#    'Description': '8286/1',
#    'Longitude': -1.5077707856946,
#    'Latitude': 52.9272738204074,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8469',
#    'Name': 'TMU Site 8287/1 on link A38 southbound between A6 and A52; GPS Ref: 433814;337444; Southbound',
#    'Description': '8287/1',
#    'Longitude': -1.49837355291515,
#    'Latitude': 52.9333564598404,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8471',
#    'Name': 'TMU Site 8288/1 on link A38 northbound exit for A6; GPS Ref: 434858;339238; Northbound',
#    'Description': '8288/1',
#    'Longitude': -1.48264994255545,
#    'Latitude': 52.9494163246265,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8470',
#    'Name': 'TMU Site 8288/2 on link A38 northbound within the A6 junction; GPS Ref: 434864;339228; Northbound',
#    'Description': '8288/2',
#    'Longitude': -1.48256171925507,
#    'Latitude': 52.9493260476909,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9018',
#    'Name': 'TMU Site 8289/1 on link A38 southbound exit for A6; GPS Ref: 435233;339436; Southbound',
#    'Description': '8289/1',
#    'Longitude': -1.47704760334588,
#    'Latitude': 52.9511717971075,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '8472',
#    'Name': 'TMU Site 8289/2 on link A38 southbound within the A6 junction; GPS Ref: 435230;339445; Southbound',
#    'Description': '8289/2',
#    'Longitude': -1.47709127796309,
#    'Latitude': 52.951252893416,
#    'Status': 'Active',
#    'Quality': 91}],
#  'E06000016': [],
#  'E06000017': [{'Id': '8095',
#    'Name': 'TMU Site 6507/1 on link A1 northbound exit for A6121; GPS Ref: 501287;306351; Northbound',
#    'Description': '6507/1',
#    'Longitude': -0.504397827683138,
#    'Latitude': 52.6454699009878,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8094',
#    'Name': 'TMU Site 6507/2 on link A1 northbound within the A6121 junction; GPS Ref: 501295;306372; Northbound',
#    'Description': '6507/2',
#    'Longitude': -0.504273193989,
#    'Latitude': 52.6456571328881,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8097',
#    'Name': 'TMU Site 6508/1 on link A1 southbound exit for A6121; GPS Ref: 501145;306633; Southbound',
#    'Description': '6508/1',
#    'Longitude': -0.506409536053058,
#    'Latitude': 52.648030663352,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8099',
#    'Name': 'TMU Site 6510/1 on link A1 northbound exit for A606; GPS Ref: 500715;307262; Northbound',
#    'Description': '6510/1',
#    'Longitude': -0.512571257658593,
#    'Latitude': 52.6537633181615,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8098',
#    'Name': 'TMU Site 6510/2 on link A1 northbound within the A606 junction; GPS Ref: 500728;307285; Northbound',
#    'Description': '6510/2',
#    'Longitude': -0.512372138025147,
#    'Latitude': 52.6539676051128,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8101',
#    'Name': 'TMU Site 6511/1 on link A1 southbound exit for A606; GPS Ref: 500621;307570; Southbound',
#    'Description': '6511/1',
#    'Longitude': -0.513866504498621,
#    'Latitude': 52.6565487007014,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '8100',
#    'Name': 'TMU Site 6511/2 on link A1 southbound within the A606 junction; GPS Ref: 500615;307537; Southbound',
#    'Description': '6511/2',
#    'Longitude': -0.513965227715336,
#    'Latitude': 52.6562532456413,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '8103',
#    'Name': 'TMU Site 6513/1 on link A1 southbound between B668 and B1081 near Stamford (north); GPS Ref: 496832;311817; Southbound',
#    'Description': '6513/1',
#    'Longitude': -0.568615394581517,
#    'Latitude': 52.6954052326412,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E06000018': [{'Id': '9070',
#    'Name': 'TMU Site 6555/1 on A52 eastbound between A6464 and A6514; GPS Ref: 453356;338512; Eastbound',
#    'Description': '6555/1',
#    'Longitude': -1.20748574774665,
#    'Latitude': 52.9413762754487,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '9071',
#    'Name': 'TMU Site 6555/2 on A52 westbound between A6514 and A6464; GPS Ref: 453358;338508; Westbound',
#    'Description': '6555/2',
#    'Longitude': -1.20745664566449,
#    'Latitude': 52.9413401240352,
#    'Status': 'Active',
#    'Quality': 92}],
#  'E06000019': [{'Id': '8181',
#    'Name': 'TMU Site 7018/1 on link A40 eastbound between A49 and A449; GPS Ref: 359627;224951; Eastbound',
#    'Description': '7018/1',
#    'Longitude': -2.58846345477388,
#    'Latitude': 51.921615500349,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '7877',
#    'Name': 'TMU Site 7019/1 on link A40 westbound between A449 and A49; GPS Ref: 359559;224889; Westbound',
#    'Description': '7019/1',
#    'Longitude': -2.58944487689623,
#    'Latitude': 51.9210531450604,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '7875',
#    'Name': 'TMU Site 7020/1 on link A40 westbound between A49 and A4137; GPS Ref: 357357;223380; Westbound',
#    'Description': '7020/1',
#    'Longitude': -2.62127427204138,
#    'Latitude': 51.9073218661806,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '7876',
#    'Name': 'TMU Site 7021/1 on link A40 eastbound between A4137 and A49; GPS Ref: 357768;223804; Eastbound',
#    'Description': '7021/1',
#    'Longitude': -2.61535231352261,
#    'Latitude': 51.9111652191713,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '7873',
#    'Name': 'TMU Site 7023/1 on link A40 westbound between B4164 and Welsh border; GPS Ref: 353526;216719; Westbound',
#    'Description': '7023/1',
#    'Longitude': -2.67606030089611,
#    'Latitude': 51.8471290261285,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8189',
#    'Name': 'TMU Site 7024/1 on A49 northbound between A40 and A4137; GPS Ref: 355647;224955; Northbound',
#    'Description': '7024/1',
#    'Longitude': -2.64633294378636,
#    'Latitude': 51.9213477046058,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '8190',
#    'Name': 'TMU Site 7024/2 on A49 southbound between A4137 and A40; GPS Ref: 355650;224960; Southbound',
#    'Description': '7024/2',
#    'Longitude': -2.6462899700006,
#    'Latitude': 51.9213928957061,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '8192',
#    'Name': 'TMU Site 7025/1 on link A49 northbound between A4137 and A466; GPS Ref: 351461;229419; Northbound',
#    'Description': '7025/1',
#    'Longitude': -2.70782753154911,
#    'Latitude': 51.9611299185897,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8191',
#    'Name': 'TMU Site 7025/2 on link A49 southbound between A466 and A4137; GPS Ref: 351466;229420; Southbound',
#    'Description': '7025/2',
#    'Longitude': -2.70775491030131,
#    'Latitude': 51.9611393465238,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '8193',
#    'Name': 'TMU Site 7026/1 on link A49 southbound between B4399 and A466; GPS Ref: 350212;236046; Southbound',
#    'Description': '7026/1',
#    'Longitude': -2.72696776673976,
#    'Latitude': 52.0205965845409,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '10687',
#    'Name': 'TMU Site 7026/2 on link A49 northbound between A466 and B4399; GPS Ref: 350202;236049; Northbound',
#    'Description': '7026/2',
#    'Longitude': -2.72711391872753,
#    'Latitude': 52.0206226545636,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8196',
#    'Name': 'TMU Site 7029/1 on A49 northbound between B4361 and A44 near Leominster (south); GPS Ref: 350802;256581; Northbound',
#    'Description': '7029/1',
#    'Longitude': -2.72134162158477,
#    'Latitude': 52.2052572241925,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8197',
#    'Name': 'TMU Site 7029/2 on A49 southbound between A44 near Leominster (south) and B4361; GPS Ref: 350807;256582; Southbound',
#    'Description': '7029/2',
#    'Longitude': -2.7212686064217,
#    'Latitude': 52.2052666620012,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '9084',
#    'Name': 'TMU Site 7248/1 on link A49 northbound between A465 and A438 near Hereford (south); GPS Ref: 350745;239452; Northbound',
#    'Description': '7248/1',
#    'Longitude': -2.71969268768606,
#    'Latitude': 52.051263933692,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9085',
#    'Name': 'TMU Site 7248/2 on link A49 southbound between A438 near Hereford (north) and A465; GPS Ref: 350750;239450; Southbound',
#    'Description': '7248/2',
#    'Longitude': -2.71961949140948,
#    'Latitude': 52.0512463994414,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E06000020': [],
#  'E06000021': [{'Id': '9090',
#    'Name': 'TMU Site 7547/1 on link A500 southbound within the A34 near Stoke-on-Trent (south) junction; GPS Ref: 386861;342866; Southbound',
#    'Description': '7547/1',
#    'Longitude': -2.19714695202194,
#    'Latitude': 52.9829889730792,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '9091',
#    'Name': 'TMU Site 7548/1 on link A500 northbound within the A34 near Stoke-on-Trent (south) junction; GPS Ref: 386516;342709; Northbound',
#    'Description': '7548/1',
#    'Longitude': -2.20227891281546,
#    'Latitude': 52.9815689934558,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9094',
#    'Name': 'TMU Site 7550/3 on A500 southbound within the A50 junction; GPS Ref: 387638;343498; Southbound',
#    'Description': '7550/3',
#    'Longitude': -2.1855983563343,
#    'Latitude': 52.988688868094,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '9097',
#    'Name': 'TMU Site 7551/2 on link A500 northbound within the A50 junction; GPS Ref: 387631;343506; Northbound',
#    'Description': '7551/2',
#    'Longitude': -2.18570293995702,
#    'Latitude': 52.9887606194888,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '8430',
#    'Name': 'TMU Site 7552/1 on link A50 northbound access from A5006; GPS Ref: 387692;343603; Northbound',
#    'Description': '7552/1',
#    'Longitude': -2.184797978626,
#    'Latitude': 52.9896339938238,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8428',
#    'Name': 'TMU Site 7555/1 on link A50 eastbound distributor between B5490 and A5007 near Longton (west); GPS Ref: 389010;343733; Eastbound',
#    'Description': '7555/1',
#    'Longitude': -2.16516843991729,
#    'Latitude': 52.990831450502,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9350',
#    'Name': 'TMU Site 7555/2 on A50 eastbound access from B5490; GPS Ref: 389011;343716; Eastbound',
#    'Description': '7555/2',
#    'Longitude': -2.1651529614195,
#    'Latitude': 52.9906786550224,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8427',
#    'Name': 'TMU Site 7555/3 on link A50 eastbound within the B5490 junction; GPS Ref: 389010;343707; Eastbound',
#    'Description': '7555/3',
#    'Longitude': -2.16516755084391,
#    'Latitude': 52.9905977317014,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8429',
#    'Name': 'TMU Site 7556/1 on link A50 westbound within the A5007 near Longton (west) junction; GPS Ref: 389743;343784; Westbound',
#    'Description': '7556/1',
#    'Longitude': -2.15425038204295,
#    'Latitude': 52.9913045225896,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '8422',
#    'Name': 'TMU Site 7561/1 on link A50 westbound exit for A520; GPS Ref: 393391;342129; Westbound',
#    'Description': '7561/1',
#    'Longitude': -2.09987016312028,
#    'Latitude': 52.9764856963304,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8421',
#    'Name': 'TMU Site 7561/2 on link A50 westbound within the A520 junction; GPS Ref: 393398;342133; Westbound',
#    'Description': '7561/2',
#    'Longitude': -2.09976599450412,
#    'Latitude': 52.9765217498447,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8998',
#    'Name': 'TMU Site 7654/1 on A50 westbound within the A5005/A5035 junction; GPS Ref: 391107;343056; Westbound',
#    'Description': '7654/1',
#    'Longitude': -2.13391012647805,
#    'Latitude': 52.9847849499405,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9287',
#    'Name': 'TMU Site 9909/1 on A500 northbound between A34 near Stoke-on-Trent (south) and A50; GPS Ref: 387227;343179; Northbound',
#    'Description': '9909/1',
#    'Longitude': -2.19170807339683,
#    'Latitude': 52.9858115646195,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9288',
#    'Name': 'TMU Site 9909/2 on A500 southbound between A50 and A34 near Stoke-on-Trent (south); GPS Ref: 387240;343167; Southbound',
#    'Description': '9909/2',
#    'Longitude': -2.19151395532618,
#    'Latitude': 52.9857040052905,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E06000022': [{'Id': '9564',
#    'Name': 'TMU Site 5337/1 on A4 westbound between A363 and A46; GPS Ref: 377793;166703; Westbound',
#    'Description': '5337/1',
#    'Longitude': -2.32059862455693,
#    'Latitude': 51.3989173853394,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '9565',
#    'Name': 'TMU Site 5337/2 on A4 eastbound between A46 and A363; GPS Ref: 377788;166713; Eastbound',
#    'Description': '5337/2',
#    'Longitude': -2.32067112511769,
#    'Latitude': 51.3990071043582,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '9582',
#    'Name': 'TMU Site 5660/1 on A36 northbound between A366 and A4; GPS Ref: 377859;160049; Northbound',
#    'Description': '5660/1',
#    'Longitude': -2.31923319388236,
#    'Latitude': 51.3390897407954,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9583',
#    'Name': 'TMU Site 5660/2 on A36 southbound between A4 and A366; GPS Ref: 377864;160050; Southbound',
#    'Description': '5660/2',
#    'Longitude': -2.31916147884926,
#    'Latitude': 51.3390989281174,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9576',
#    'Name': 'TMU Site 5661/1 on A36 northbound between A366 and A4; GPS Ref: 377892;165861; Northbound',
#    'Description': '5661/1',
#    'Longitude': -2.3191228850787,
#    'Latitude': 51.3913503268149,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '9577',
#    'Name': 'TMU Site 5661/2 on A36 southbound between A4 and A366; GPS Ref: 377895;165863; Southbound',
#    'Description': '5661/2',
#    'Longitude': -2.31907989453528,
#    'Latitude': 51.391368427571,
#    'Status': 'Active',
#    'Quality': 94}],
#  'E06000023': [],
#  'E06000024': [],
#  'E06000025': [{'Id': '9560',
#    'Name': 'TMU Site 5335/1 on A46 northbound between A420 and M4; GPS Ref: 374855;175234; Northbound',
#    'Description': '5335/1',
#    'Longitude': -2.36343824405329,
#    'Latitude': 51.4755007634065,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9561',
#    'Name': 'TMU Site 5335/2 on A46 southbound between M4 and A420; GPS Ref: 374857;175232; Southbound',
#    'Description': '5335/2',
#    'Longitude': -2.36340930444528,
#    'Latitude': 51.4754828698145,
#    'Status': 'Active',
#    'Quality': 96}],
#  'E06000026': [{'Id': '7373',
#    'Name': 'TMU Site 5047/1 on A38 eastbound between A386 and A374 near Plymouth; GPS Ref: 250101;57153; Eastbound',
#    'Description': '5047/1',
#    'Longitude': -4.11034430350359,
#    'Latitude': 50.3950820062428,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '7372',
#    'Name': 'TMU Site 5048/1 on A38 westbound between A374 near Plymouth and A386; GPS Ref: 249503;57267; Westbound',
#    'Description': '5048/1',
#    'Longitude': -4.11879762760676,
#    'Latitude': 50.3959538232296,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '7375',
#    'Name': 'TMU Site 5049/1 on link A38 eastbound between A3064 and A386; GPS Ref: 247388;58094; Eastbound',
#    'Description': '5049/1',
#    'Longitude': -4.14886908417076,
#    'Latitude': 50.4028406425811,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '7374',
#    'Name': 'TMU Site 5050/1 on link A38 westbound between A386 and A3064; GPS Ref: 246908;58205; Westbound',
#    'Description': '5050/1',
#    'Longitude': -4.15566383485644,
#    'Latitude': 50.4037131918174,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '7376',
#    'Name': 'TMU Site 5052/1 on A38 westbound between A3064 and B3413; GPS Ref: 245927;58901; Westbound',
#    'Description': '5052/1',
#    'Longitude': -4.16974417433595,
#    'Latitude': 50.4097112868317,
#    'Status': 'Active',
#    'Quality': 93}],
#  'E06000027': [],
#  'E06000030': [{'Id': '7446',
#    'Name': 'TMU Site 5306/1 on link A419 southbound between B4019 and A361; GPS Ref: 416331;188752; Southbound',
#    'Description': '5306/1',
#    'Longitude': -1.76561304689391,
#    'Latitude': 51.5973802499327,
#    'Status': 'Active',
#    'Quality': 94}],
#  'E06000031': [{'Id': '8052',
#    'Name': 'TMU Site 6352/1 on link A47 eastbound between A1260 and A15 near Peterborough (west); GPS Ref: 516253;299071; Eastbound',
#    'Description': '6352/1',
#    'Longitude': -0.285853575150945,
#    'Latitude': 52.5770568539132,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8053',
#    'Name': 'TMU Site 6353/1 on link A47 westbound between A15 near Peterborough (west) and A1260; GPS Ref: 516470;299452; Westbound',
#    'Description': '6353/1',
#    'Longitude': -0.282519095531066,
#    'Latitude': 52.580434152253,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8087',
#    'Name': 'TMU Site 6502/1 on link A1 northbound exit for A47; GPS Ref: 507452;299848; Northbound',
#    'Description': '6502/1',
#    'Longitude': -0.415424959799212,
#    'Latitude': 52.5858467160328,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8086',
#    'Name': 'TMU Site 6502/2 on link A1 northbound within the A47 junction; GPS Ref: 507479;299884; Northbound',
#    'Description': '6502/2',
#    'Longitude': -0.415014929696076,
#    'Latitude': 52.5861648972587,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8088',
#    'Name': 'TMU Site 6503/2 on link A1 southbound within the A47 junction; GPS Ref: 507499;299861; Southbound',
#    'Description': '6503/2',
#    'Longitude': -0.414727303795606,
#    'Latitude': 52.5859542621935,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8090',
#    'Name': 'TMU Site 6504/1 on link A1 northbound between A47 and B1081 near Stamford (south); GPS Ref: 506638;301788; Northbound',
#    'Description': '6504/1',
#    'Longitude': -0.42681090683493,
#    'Latitude': 52.6034407158026,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8091',
#    'Name': 'TMU Site 6505/1 on link A1 northbound between B1081 near Stamford (south) and A43; GPS Ref: 503139;305176; Northbound',
#    'Description': '6505/1',
#    'Longitude': -0.47740187429315,
#    'Latitude': 52.6345618811409,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8093',
#    'Name': 'TMU Site 6506/1 on link A1 southbound exit for A43; GPS Ref: 502214;305641; Southbound',
#    'Description': '6506/1',
#    'Longitude': -0.490921261017337,
#    'Latitude': 52.6389155767986,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8092',
#    'Name': 'TMU Site 6506/2 on link A1 southbound between A43 and B1081 near Stamford (south); GPS Ref: 502214;305628; Southbound',
#    'Description': '6506/2',
#    'Longitude': -0.490925279784949,
#    'Latitude': 52.6387987480907,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8158',
#    'Name': 'TMU Site 6604/1 on link A47 westbound between A1260 and A1; GPS Ref: 507967;299702; Westbound',
#    'Description': '6604/1',
#    'Longitude': -0.407874162157131,
#    'Latitude': 52.5844328193545,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8157',
#    'Name': 'TMU Site 6604/2 on link A47 eastbound between A1 and A1260; GPS Ref: 507968;299709; Eastbound',
#    'Description': '6604/2',
#    'Longitude': -0.407857130058527,
#    'Latitude': 52.5844955262948,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '7810',
#    'Name': 'TMU Site 6783/1 on link A1 southbound exit for A1(M)/A605/A1139; GPS Ref: 513995;294435; Southbound',
#    'Description': '6783/1',
#    'Longitude': -0.320749460070192,
#    'Latitude': 52.5358747862467,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9483',
#    'Name': 'TMU Site 7156/1 on A47 westbound between B1167 near Thorney (east) and B1040; GPS Ref: 529777;304653; Westbound',
#    'Description': '7156/1',
#    'Longitude': -0.084203551966424,
#    'Latitude': 52.6241542375248,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9484',
#    'Name': 'TMU Site 7157/1 on A47 eastbound between B1040 and B1167 near Thorney (east); GPS Ref: 530130;304600; Eastbound',
#    'Description': '7157/1',
#    'Longitude': -0.07901256884177,
#    'Latitude': 52.6235936185247,
#    'Status': 'Active',
#    'Quality': 97}],
#  'E06000032': [],
#  'E06000033': [],
#  'E06000034': [{'Id': '7787',
#    'Name': 'TMU Site 6059/1 on link A13 eastbound exit for A1012; GPS Ref: 560635;180204; Eastbound',
#    'Description': '6059/1',
#    'Longitude': 0.312806361881438,
#    'Latitude': 51.4979552300202,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '7788',
#    'Name': 'TMU Site 6060/2 on link A13 westbound within the A1012 junction; GPS Ref: 560981;180566; Westbound',
#    'Description': '6060/2',
#    'Longitude': 0.317951662330994,
#    'Latitude': 51.5011091971924,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '7771',
#    'Name': 'TMU Site 6064/1 on link A1089 southbound between A13 and A126; GPS Ref: 563885;179567; Southbound',
#    'Description': '6064/1',
#    'Longitude': 0.359290077261242,
#    'Latitude': 51.4913008389108,
#    'Status': 'Active',
#    'Quality': 97}],
#  'E06000035': [],
#  'E06000036': [],
#  'E06000037': [{'Id': '7252',
#    'Name': 'TMU Site 5614/1 on link A34 northbound exit for A4; GPS Ref: 445035;168295; Northbound',
#    'Description': '5614/1',
#    'Longitude': -1.35383420887521,
#    'Latitude': 51.4118936509925,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '7251',
#    'Name': 'TMU Site 5614/2 on link A34 northbound within the A4 junction; GPS Ref: 445044;168293; Northbound',
#    'Description': '5614/2',
#    'Longitude': -1.35370506075714,
#    'Latitude': 51.4118749564221,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '8908',
#    'Name': 'TMU Site 5730/1 on A34 southbound exit for M4; GPS Ref: 448028;173356; Southbound',
#    'Description': '5730/1',
#    'Longitude': -1.3101174794404,
#    'Latitude': 51.457152357958,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '9351',
#    'Name': 'TMU Site 7046/1 on link A34 northbound between M4 and A4185; GPS Ref: 448513;175493; Northbound',
#    'Description': '7046/1',
#    'Longitude': -1.30284505359691,
#    'Latitude': 51.4763248306238,
#    'Status': 'Active',
#    'Quality': 90}],
#  'E06000038': [],
#  'E06000039': [],
#  'E06000040': [{'Id': '7574',
#    'Name': 'TMU Site 5632/1 on link A308(M) eastbound between M4/A404(M) and A308; GPS Ref: 489001;179028; Eastbound',
#    'Description': '5632/1',
#    'Longitude': -0.719099141615601,
#    'Latitude': 51.5031922387501,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '7575',
#    'Name': 'TMU Site 5633/1 on link A308(M) westbound between A308 and M4/A404(M); GPS Ref: 489137;179050; Westbound',
#    'Description': '5633/1',
#    'Longitude': -0.71713465957363,
#    'Latitude': 51.5033685613965,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '7280',
#    'Name': 'TMU Site 5645/1 on link A404 southbound access from A4130; GPS Ref: 484514;181740; Southbound',
#    'Description': '5645/1',
#    'Longitude': -0.783078173062537,
#    'Latitude': 51.5282589746326,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '7279',
#    'Name': 'TMU Site 5645/2 on link A404 southbound within the A4130 junction; GPS Ref: 484495;181731; Southbound',
#    'Description': '5645/2',
#    'Longitude': -0.783354154178959,
#    'Latitude': 51.5281809080382,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '7282',
#    'Name': 'TMU Site 5647/1 on link A404 southbound between A4155 and A308; GPS Ref: 485717;185491; Southbound',
#    'Description': '5647/1',
#    'Longitude': -0.764828772667231,
#    'Latitude': 51.5617975353038,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '7292',
#    'Name': 'TMU Site 5677/1 on link A404(M) J9A northbound exit; GPS Ref: 487685;179522; Northbound',
#    'Description': '5677/1',
#    'Longitude': -0.737931548310948,
#    'Latitude': 51.5078384000992,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '7291',
#    'Name': 'TMU Site 5677/2 on link A404(M) northbound within J9A; GPS Ref: 487688;179553; Northbound',
#    'Description': '5677/2',
#    'Longitude': -0.73788062253094,
#    'Latitude': 51.5081166031386,
#    'Status': 'Active',
#    'Quality': 91}],
#  'E06000041': [],
#  'E06000042': [{'Id': '7865',
#    'Name': 'TMU Site 6851/1 on link A5 northbound between A422 and A422/A508; GPS Ref: 479177;241033; Northbound',
#    'Description': '6851/1',
#    'Longitude': -0.846478890105326,
#    'Latitude': 52.0620379532971,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '7866',
#    'Name': 'TMU Site 6852/1 on link A5 southbound between A422/A508 and A422; GPS Ref: 479474;240807; Southbound',
#    'Description': '6852/1',
#    'Longitude': -0.842199891298716,
#    'Latitude': 52.0599639140015,
#    'Status': 'Active',
#    'Quality': 96}],
#  'E06000043': [{'Id': '7746',
#    'Name': 'TMU Site 5772/2 on link A27 eastbound within the A23 junction before A23 southbound exit; GPS Ref: 529598;109152; Eastbound',
#    'Description': '5772/2',
#    'Longitude': -0.159652232027841,
#    'Latitude': 50.8673487535167,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '7685',
#    'Name': 'TMU Site 5773/1 on link connector at A23/A27; GPS Ref: 529818;109269; Carriageway Connector',
#    'Description': '5773/1',
#    'Longitude': -0.156486164037225,
#    'Latitude': 50.8683510119334,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '7684',
#    'Name': 'TMU Site 5773/2 on link connector at A23/A27; GPS Ref: 529809;109259; Southbound',
#    'Description': '5773/2',
#    'Longitude': -0.156617535584698,
#    'Latitude': 50.8682631530127,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '7743',
#    'Name': 'TMU Site 5776/1 on link A27 eastbound access from A270 near Brighton (east); GPS Ref: 534253;108586; Eastbound',
#    'Description': '5776/1',
#    'Longitude': -0.093747232394584,
#    'Latitude': 50.8612009449525,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '7742',
#    'Name': 'TMU Site 5776/2 on link A27 eastbound between A23 and A270 near Brighton (east); GPS Ref: 534266;108573; Eastbound',
#    'Description': '5776/2',
#    'Longitude': -0.093567388344581,
#    'Latitude': 50.8610810919503,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '9048',
#    'Name': 'TMU Site 5990/1 on link A27 westbound exit for A2038; GPS Ref: 528596;108256; Westbound',
#    'Description': '5990/1',
#    'Longitude': -0.174198374784164,
#    'Latitude': 50.8595190828391,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '9047',
#    'Name': 'TMU Site 5990/2 on link A27 westbound within the A2038 junction; GPS Ref: 528585;108272; Westbound',
#    'Description': '5990/2',
#    'Longitude': -0.174348965252615,
#    'Latitude': 50.8596653320791,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '9050',
#    'Name': 'TMU Site 5991/1 on A27 eastbound exit at a minor junction between A23 and A270 near Brighton (east); GPS Ref: 532022;109630; Eastbound',
#    'Description': '5991/1',
#    'Longitude': -0.125052872311262,
#    'Latitude': 50.8710971585725,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '9049',
#    'Name': 'TMU Site 5991/2 on A27 eastbound at a minor junction between A23 and A270 near Brighton (east); GPS Ref: 532019;109608; Eastbound',
#    'Description': '5991/2',
#    'Longitude': -0.12510341616905,
#    'Latitude': 50.8709001136855,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E06000044': [{'Id': '9864',
#    'Name': 'MIDAS site at A27/9472A priority 1 on link 103014701; GPS Ref: 466355;104447; Eastbound',
#    'Description': 'A27/9472A',
#    'Longitude': -1.05905889505509,
#    'Latitude': 50.8357494593955,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9982',
#    'Name': 'MIDAS site at A27/9476B priority 1 on link 103004001; GPS Ref: 466704;104291; Westbound',
#    'Description': 'A27/9476B',
#    'Longitude': -1.05413165235902,
#    'Latitude': 50.8343065322399,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9960',
#    'Name': 'MIDAS site at A27/9481J priority 1 on link 103014901; GPS Ref: 467100;104289; Eastbound',
#    'Description': 'A27/9481J',
#    'Longitude': -1.04850934449068,
#    'Latitude': 50.8342427868392,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '9826',
#    'Name': 'MIDAS site at A27/9485A priority 1 on link 103014601; GPS Ref: 467602;104380; Eastbound',
#    'Description': 'A27/9485A',
#    'Longitude': -1.04136477395217,
#    'Latitude': 50.8350026978759,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '10101',
# ...
#    'Quality': 94},
#   {'Id': '1039',
#    'Name': 'MIDAS site at A1M/9385A priority 1 on link 200014167; GPS Ref: 447913;422579; Northbound',
#    'Description': 'A1M/9385A',
#    'Longitude': -1.27580297675135,
#    'Latitude': 53.697478320228,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '2315',
#    'Name': 'MIDAS site at A1M/9388B priority 1 on link 200014145; GPS Ref: 447916;422859; Southbound',
#    'Description': 'A1M/9388B',
#    'Longitude': -1.27571450742519,
#    'Latitude': 53.6999944633999,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '4949',
#    'Name': 'MIDAS site at A1M/9390A priority 1 on link 200014167; GPS Ref: 447851;423072; Northbound',
#    'Description': 'A1M/9390A',
#    'Longitude': -1.27666630413258,
#    'Latitude': 53.7019147084091,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '3421',
#    'Name': 'MIDAS site at A1M/9392B priority 1 on link 200014146; GPS Ref: 447823;423249; Southbound',
#    'Description': 'A1M/9392B',
#    'Longitude': -1.27706334496039,
#    'Latitude': 53.7035080355043,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '3868',
#    'Name': 'MIDAS site at A1M/9393A priority 1 on link 200014167; GPS Ref: 447758;423354; Northbound',
#    'Description': 'A1M/9393A',
#    'Longitude': -1.27803182570983,
#    'Latitude': 53.7044576433014,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '3333',
#    'Name': 'MIDAS site at A1M/9396B priority 1 on link 200014152; GPS Ref: 447656;423628; Southbound',
#    'Description': 'A1M/9396B',
#    'Longitude': -1.27953509372529,
#    'Latitude': 53.7069294816884,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '993',
#    'Name': 'MIDAS site at A1M/9397M priority 1 on link 200014149; GPS Ref: 447612;423715; Southbound',
#    'Description': 'A1M/9397M',
#    'Longitude': -1.28018836783505,
#    'Latitude': 53.7077153872953,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '2385',
#    'Name': 'MIDAS site at A1M/9398A priority 1 on link 200014167; GPS Ref: 447515;423786; Northbound',
#    'Description': 'A1M/9398A',
#    'Longitude': -1.2816469495425,
#    'Latitude': 53.7083623021875,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '4492',
#    'Name': 'MIDAS site at A1M/9400B priority 1 on link 200014152; GPS Ref: 447424;423935; Southbound',
#    'Description': 'A1M/9400B',
#    'Longitude': -1.28300289588087,
#    'Latitude': 53.7097096735488,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '1177',
#    'Name': 'MIDAS site at A1M/9401A priority 1 on link 200014150; GPS Ref: 447319;424032; Northbound',
#    'Description': 'A1M/9401A',
#    'Longitude': -1.28457877576044,
#    'Latitude': 53.7105909528537,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '5073',
#    'Name': 'MIDAS site at A1M/9402M priority 1 on link 200014149; GPS Ref: 447098;424105; Southbound',
#    'Description': 'A1M/9402M',
#    'Longitude': -1.28791568235008,
#    'Latitude': 53.711266959169,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '998',
#    'Name': 'MIDAS site at A1M/9404L priority 1 on link 200017493; GPS Ref: 446884;424144; Westbound',
#    'Description': 'A1M/9404L',
#    'Longitude': -1.29115169006158,
#    'Latitude': 53.7116366802162,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '1653',
#    'Name': 'MIDAS site at A1M/9405K priority 1 on link 200017495; GPS Ref: 446895;424289; Westbound',
#    'Description': 'A1M/9405K',
#    'Longitude': -1.29096323889515,
#    'Latitude': 53.7129388714057,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '2910',
#    'Name': 'MIDAS site at A1M/9406L priority 1 on link 200017493; GPS Ref: 446991;424336; Westbound',
#    'Description': 'A1M/9406L',
#    'Longitude': -1.28950178841651,
#    'Latitude': 53.7133526727533,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '3726',
#    'Name': 'MIDAS site at A1M/9406M priority 1 on link 200014149; GPS Ref: 446682;424173; Southbound',
#    'Description': 'A1M/9406M',
#    'Longitude': -1.29420746845397,
#    'Latitude': 53.7119153680877,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '2911',
#    'Name': 'MIDAS site at A1M/9411A priority 1 on link 200013599; GPS Ref: 446971;424936; Northbound',
#    'Description': 'A1M/9411A',
#    'Longitude': -1.28971433635918,
#    'Latitude': 53.7187469210177,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '167',
#    'Name': 'MIDAS site at A1M/9411B priority 1 on link 200014152; GPS Ref: 446995;424913; Southbound',
#    'Description': 'A1M/9411B',
#    'Longitude': -1.28935416303615,
#    'Latitude': 53.7185380591633,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '4684',
#    'Name': 'MIDAS site at A1M/9415B priority 1 on link 200013598; GPS Ref: 446999;425316; Southbound',
#    'Description': 'A1M/9415B',
#    'Longitude': -1.28923252573605,
#    'Latitude': 53.7221595710854,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '573',
#    'Name': 'MIDAS site at A1M/9417A priority 1 on link 200013599; GPS Ref: 446980;425536; Northbound',
#    'Description': 'A1M/9417A',
#    'Longitude': -1.28948712393962,
#    'Latitude': 53.7241384735602,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '514',
#    'Name': 'MIDAS site at A1M/9419B priority 1 on link 200013598; GPS Ref: 447005;425710; Southbound',
#    'Description': 'A1M/9419B',
#    'Longitude': -1.2890819114781,
#    'Latitude': 53.7257000136799,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '4111',
#    'Name': 'MIDAS site at A1M/9421A priority 1 on link 200013599; GPS Ref: 446983;425936; Northbound',
#    'Description': 'A1M/9421A',
#    'Longitude': -1.28938107891,
#    'Latitude': 53.7277331079685,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '1295',
#    'Name': 'MIDAS site at A1M/9423B priority 0 on link 200013598; GPS Ref: 447018;426111; Southbound',
#    'Description': 'A1M/9423B',
#    'Longitude': -1.28882411564039,
#    'Latitude': 53.7293027345364,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '802',
#    'Name': 'MIDAS site at A1M/9426A priority 1 on link 200013599; GPS Ref: 447073;426444; Northbound',
#    'Description': 'A1M/9426A',
#    'Longitude': -1.28793999745622,
#    'Latitude': 53.7322905440408,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '2917',
#    'Name': 'MIDAS site at A1M/9428B priority 1 on link 200013598; GPS Ref: 447157;426570; Southbound',
#    'Description': 'A1M/9428B',
#    'Longitude': -1.2866476581659,
#    'Latitude': 53.7334153772592,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E08000037': [{'Id': '8354',
#    'Name': 'TMU Site 9304/1 on link A1(M) J64 northbound exit; GPS Ref: 428327;554342; Northbound',
#    'Description': '9304/1',
#    'Longitude': -1.56000771803451,
#    'Latitude': 54.8830421306319,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8353',
#    'Name': 'TMU Site 9304/2 on link A1(M) northbound within J64; GPS Ref: 428349;554340; Northbound',
#    'Description': '9304/2',
#    'Longitude': -1.55966501834813,
#    'Latitude': 54.8830229177479,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8356',
#    'Name': 'TMU Site 9305/1 on link A1(M) J64 southbound exit; GPS Ref: 428400;554679; Southbound',
#    'Description': '9305/1',
#    'Longitude': -1.55883678599737,
#    'Latitude': 54.8860662646151,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8355',
#    'Name': 'TMU Site 9305/2 on link A1(M) southbound within J64; GPS Ref: 428376;554678; Southbound',
#    'Description': '9305/2',
#    'Longitude': -1.55921098061037,
#    'Latitude': 54.8860586350296,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8803',
#    'Name': 'TMU Site 9802/1 on link A1 northbound exit for A694/A69; GPS Ref: 419928;562627; Northbound',
#    'Description': '9802/1',
#    'Longitude': -1.69034924101733,
#    'Latitude': 54.9578942152188,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '8802',
#    'Name': 'TMU Site 9802/2 on link A1 northbound within the A694/A69 junction; GPS Ref: 419940;562638; Northbound',
#    'Description': '9802/2',
#    'Longitude': -1.69016109611293,
#    'Latitude': 54.9579925840074,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '8791',
#    'Name': 'TMU Site 9808/1 on link A1 northbound exit for A184; GPS Ref: 423396;561290; Northbound',
#    'Description': '9808/1',
#    'Longitude': -1.63630266842349,
#    'Latitude': 54.9457304161233,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8790',
#    'Name': 'TMU Site 9808/2 on link A1 northbound within the A184 junction; GPS Ref: 423413;561310; Northbound',
#    'Description': '9808/2',
#    'Longitude': -1.63603566568743,
#    'Latitude': 54.9459093427898,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '8789',
#    'Name': 'TMU Site 9809/1 on link A1 southbound exit for A692; GPS Ref: 423716;560950; Southbound',
#    'Description': '9809/1',
#    'Longitude': -1.6313351705009,
#    'Latitude': 54.9426602495088,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8788',
#    'Name': 'TMU Site 9809/2 on link A1 southbound within the A692 junction; GPS Ref: 423698;560946; Southbound',
#    'Description': '9809/2',
#    'Longitude': -1.63161646932994,
#    'Latitude': 54.9426251538304,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8784',
#    'Name': 'TMU Site 9811/2 on A1 southbound at a minor junction between A692 and A167 near Washington Birtley; GPS Ref: 424738;558573; Southbound',
#    'Description': '9811/2',
#    'Longitude': -1.61558584006745,
#    'Latitude': 54.9212516258228,
#    'Status': 'Active',
#    'Quality': 93},
#   {'Id': '8782',
#    'Name': 'TMU Site 9812/2 on A1 northbound at a minor junction between A167 near Washington Birtley and A692; GPS Ref: 425214;558541; Northbound',
#    'Description': '9812/2',
#    'Longitude': -1.60816228126228,
#    'Latitude': 54.9209404139593,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8781',
#    'Name': 'TMU Site 9813/1 on link A1 southbound exit for A167 near Washington Birtley; GPS Ref: 426345;557723; Southbound',
#    'Description': '9813/1',
#    'Longitude': -1.59059191872347,
#    'Latitude': 54.9135316900426,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '8780',
#    'Name': 'TMU Site 9813/2 on link A1 southbound within the A167 near Washington Birtley junction; GPS Ref: 426331;557708; Southbound',
#    'Description': '9813/2',
#    'Longitude': -1.59081165910391,
#    'Latitude': 54.9133976347209,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '14377',
#    'Name': 'TMU Site 9957/1 on link A1 northbound access from A692; GPS Ref: 423672;560957; Northbound',
#    'Description': '9957/1',
#    'Longitude': -1.63202141415019,
#    'Latitude': 54.9427252216109,
#    'Status': 'Active',
#    'Quality': 92},
#   {'Id': '911',
#    'Name': 'MIDAS site at A1/9537A priority 1 on link 120022501; GPS Ref: 428277;556429; Northbound',
#    'Description': 'A1/9537A',
#    'Longitude': -1.56058277200349,
#    'Latitude': 54.9017985869767,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '3636',
#    'Name': 'MIDAS site at A1/9552A priority 1 on link 120014001; GPS Ref: 427087;557334; Northbound',
#    'Description': 'A1/9552A',
#    'Longitude': -1.57905445809633,
#    'Latitude': 54.9099965977627,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '3523',
#    'Name': 'MIDAS site at A1/9552J priority 1 on link 120013701; GPS Ref: 427083;557326; Northbound',
#    'Description': 'A1/9552J',
#    'Longitude': -1.57911759392346,
#    'Latitude': 54.9099249256479,
#    'Status': 'Active',
#    'Quality': 94},
#   {'Id': '3187',
#    'Name': 'MIDAS site at A194M/9537A priority 1 on link 120008401; GPS Ref: 428324;556433; Northbound',
#    'Description': 'A194M/9537A',
#    'Longitude': -1.55984949116873,
#    'Latitude': 54.9018318825483,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '5923',
#    'Name': 'MIDAS site at A1M/9517A priority 1 on link 120006401; GPS Ref: 428353;554417; Northbound',
#    'Description': 'A1M/9517A',
#    'Longitude': -1.55959511450985,
#    'Latitude': 54.883714608161,
#    'Status': 'Active',
#    'Quality': 95},
#   {'Id': '668',
#    'Name': 'MIDAS site at A1M/9525A priority 1 on link 123022601; GPS Ref: 428363;555238; Northbound',
#    'Description': 'A1M/9525A',
#    'Longitude': -1.55935860688598,
#    'Latitude': 54.8910914852324,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '4668',
#    'Name': 'MIDAS site at A1M/9531A priority 1 on link 120005802; GPS Ref: 428369;555806; Northbound',
#    'Description': 'A1M/9531A',
#    'Longitude': -1.55920924963982,
#    'Latitude': 54.8961951480336,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E09000001': [],
#  'E09000002': [],
#  'E09000003': [{'Id': '7765',
#    'Name': 'TMU Site 6131/1 on A1 southbound exit for A5135; GPS Ref: 521223;196669; Southbound',
#    'Description': '6131/1',
#    'Longitude': -0.248973810371061,
#    'Latitude': 51.6557500474759,
#    'Status': 'Active',
#    'Quality': 91},
#   {'Id': '7766',
#    'Name': 'TMU Site 6131/2 on A1 southbound access from A5135; GPS Ref: 521218;196632; Southbound',
#    'Description': '6131/2',
#    'Longitude': -0.249058881775264,
#    'Latitude': 51.6554185990527,
#    'Status': 'Active',
#    'Quality': 90},
#   {'Id': '7764',
#    'Name': 'TMU Site 6131/3 on A1 southbound within the A5135 junction; GPS Ref: 521197;196659; Southbound',
#    'Description': '6131/3',
#    'Longitude': -0.249352938846302,
#    'Latitude': 51.655665782743,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E09000004': [],
#  'E09000005': [],
#  'E09000006': [{'Id': '8978',
#    'Name': 'TMU Site 6176/1 on link A20 eastbound between A223 and M25/M20; GPS Ref: 548697;170000; Eastbound',
#    'Description': '6176/1',
#    'Longitude': 0.136668554241037,
#    'Latitude': 51.4095322395661,
#    'Status': 'Active',
#    'Quality': 97},
#   {'Id': '8979',
#    'Name': 'TMU Site 6177/1 on link A20 westbound between B2173 and A223; GPS Ref: 548948;169993; Westbound',
#    'Description': '6177/1',
#    'Longitude': 0.14027190724658,
#    'Latitude': 51.409403524867,
#    'Status': 'Active',
#    'Quality': 93}],
#  'E09000007': [],
#  'E09000008': [],
#  'E09000009': [],
#  'E09000010': [],
#  'E09000011': [],
#  'E09000012': [],
#  'E09000013': [],
#  'E09000014': [],
#  'E09000015': [],
#  'E09000016': [],
#  'E09000017': [{'Id': '9368',
#    'Name': 'TMU Site 7044/1 on A3113 eastbound between M25 and A3044; GPS Ref: 504388;175287; Eastbound',
#    'Description': '7044/1',
#    'Longitude': -0.498590705433665,
#    'Latitude': 51.4669354131245,
#    'Status': 'Active',
#    'Quality': 96},
#   {'Id': '9369',
#    'Name': 'TMU Site 7045/1 on A3113 westbound between A3044 and M25; GPS Ref: 504384;175271; Westbound',
#    'Description': '7045/1',
#    'Longitude': -0.498652987691463,
#    'Latitude': 51.4667923315557,
#    'Status': 'Active',
#    'Quality': 95}],
#  'E09000018': [{'Id': '9006',
#    'Name': 'TMU Site 6180/1 on link A30 eastbound between B378 and A315; GPS Ref: 507750;173260; Eastbound',
#    'Description': '6180/1',
#    'Longitude': -0.450825028382527,
#    'Latitude': 51.4480857515236,
#    'Status': 'Active',
#    'Quality': 91}],
#  'E09000019': [],
#  'E09000020': [],
#  'E09000021': [],
#  'E09000022': [],
#  'E09000023': [],
#  'E09000024': [],
#  'E09000025': [],
#  'E09000026': [],
#  'E09000027': [],
#  'E09000028': [],
#  'E09000029': [],
#  'E09000030': [],
#  'E09000031': [],
#  'E09000032': [],
#  'E09000033': [],
#  'N09000001': [],
#  'N09000002': [],
#  'N09000003': [],
#  'N09000004': [],
#  'N09000005': [],
#  'N09000006': [],
#  'N09000007': [],
#  'N09000008': [],
#  'N09000009': [],
#  'N09000010': [],
#  'N09000011': [],
#  'S12000005': [],
#  'S12000006': [],
#  'S12000008': [],
#  'S12000010': [],
#  'S12000011': [],
#  'S12000013': [],
#  'S12000014': [],
#  'S12000017': [],
#  'S12000018': [],
#  'S12000019': [],
#  'S12000020': [],
#  'S12000021': [],
#  'S12000023': [],
#  'S12000026': [],
#  'S12000027': [],
#  'S12000028': [],
#  'S12000029': [],
#  'S12000030': [],
#  'S12000033': [],
#  'S12000034': [],
#  'S12000035': [],
#  'S12000036': [],
#  'S12000038': [],
#  'S12000039': [],
#  'S12000040': [],
#  'S12000041': [],
#  'S12000042': [],
#  'S12000045': [],
#  'S12000047': [],
#  'S12000048': [],
#  'S12000049': [],
#  'S12000050': [],
#  'W06000001': [],
#  'W06000002': [],
#  'W06000003': [],
#  'W06000004': [],
#  'W06000005': [],
#  'W06000006': [],
#  'W06000008': [],
#  'W06000009': [],
#  'W06000010': [],
#  'W06000011': [],
#  'W06000012': [],
#  'W06000013': [],
#  'W06000014': [],
#  'W06000015': [],
#  'W06000016': [],
#  'W06000018': [],
#  'W06000019': [],
#  'W06000020': [],
#  'W06000021': [],
#  'W06000022': [],
#  'W06000023': [],
#  'W06000024': []}

# %%
num_aroadsites = {key: len(value) for key, value in la_quality_countsites.items()}
merged_df["Count Sites"] = merged_df["Local Authority Code"].map(num_aroadsites)
df_merged_final = merged_df[merged_df['Count Sites']>0]
df_merged_final.reset_index(drop=True, inplace=True)
df_merged_final
# Out:
#    Local Authority Code             Local Authority_x  \
# 0             E06000002                 Middlesbrough
# 1             E06000044                    Portsmouth
# 2             E06000018                    Nottingham
# 3             E06000015                         Derby
# 4             E06000010   Kingston upon Hull, City of
# 5             E06000026                      Plymouth
# 6             E08000022                North Tyneside
# 7             E06000043             Brighton and Hove
# 8             E06000021                Stoke-on-Trent
# 9             E06000001                    Hartlepool
# 10            E08000026                      Coventry
# 11            E08000021           Newcastle upon Tyne
# 12            E08000003                    Manchester
# 13            E08000024                    Sunderland
# 14            E08000004                        Oldham
# 15            E08000037                     Gateshead
# 16            E08000005                      Rochdale
# 17            E08000029                      Solihull
# 18            E06000034                      Thurrock
# 19            E06000005                    Darlington
# 20            E06000040        Windsor and Maidenhead
# 21            E06000012       North East Lincolnshire
# 22            E08000014                        Sefton
# 23            E06000004              Stockton-on-Tees
# 24            E06000030                       Swindon
# 25            E06000003          Redcar and Cleveland
# 26            E06000014                          York
# 27            E06000042                 Milton Keynes
# 28            E08000016                      Barnsley
# 29            E08000036                     Wakefield
# 30            E06000031                  Peterborough
# 31            E06000022  Bath and North East Somerset
# 32            E06000017                       Rutland
# 33            E06000055                       Bedford
# 34            E06000025         South Gloucestershire
# 35            E08000035                         Leeds
# 36            E08000017                     Doncaster
# 37            E06000037                West Berkshire
# 38            E06000056          Central Bedfordshire
# 39            E06000050     Cheshire West and Chester
# 40            E06000061        North Northamptonshire
# 41            E06000062         West Northamptonshire
# 42            E06000060               Buckinghamshire
# 43            E06000019      Herefordshire, County of
# 44            E06000047                 County Durham
# 45            E06000011      East Riding of Yorkshire
# 46            E06000059                        Dorset
# 47            E06000051                    Shropshire
# 48            E06000054                     Wiltshire
# 49            E06000052                      Cornwall
# 50            E06000057                Northumberland
#
#                       Region  Area (km2) ONS Area \nCode  \
# 0                 North East     54.5537       E06000002
# 1                 South East     60.1359       E06000044
# 2              East Midlands     74.6132       E06000018
# 3              East Midlands     78.0311       E06000015
# 4   Yorkshire and the Humber     81.4974       E06000010
# 5                 South West     84.3699       E06000026
# 6                 North East     84.8234       E08000022
# 7                 South East     85.3860       E06000043
# 8              West Midlands     93.4485       E06000021
# 9                 North East     98.3466       E06000001
# 10             West Midlands     98.6390       E08000026
# 11                North East    115.1178       E08000021
# 12                North West    115.6483       E08000003
# 13                North East    139.6180       E08000024
# 14                North West    142.3450       E08000004
# 15                North East    144.0797       E08000037
# 16                North West    158.1283       E08000005
# 17             West Midlands    178.2821       E08000029
# 18           East of England    184.3180       E06000034
# 19                North East    197.4758       E06000005
# 20                South East    198.4272       E06000040
# 21  Yorkshire and the Humber    202.6626       E06000012
# 22                North West    202.7557       E08000014
# 23                North East    209.7309       E06000004
# 24                South West    230.0933       E06000030
# 25                North East    253.7857       E06000003
# 26  Yorkshire and the Humber    272.0148       E06000014
# 27                South East    308.6267       E06000042
# 28  Yorkshire and the Humber    329.0776       E08000016
# 29  Yorkshire and the Humber    338.6198       E08000036
# 30           East of England    343.4379       E06000031
# 31                South West    351.1235       E06000022
# 32             East Midlands    393.7490       E06000017
# 33           East of England    476.4082       E06000055
# 34                South West    536.4217       E06000025
# 35  Yorkshire and the Humber    551.7068       E08000035
# 36  Yorkshire and the Humber    568.5513       E08000017
# 37                South East    704.1694       E06000037
# 38           East of England    715.6657       E06000056
# 39                North West    941.2070       E06000050
# 40             East Midlands    986.5947       E06000061
# 41             East Midlands   1380.3956       E06000062
# 42                South East   1564.9380       E06000060
# 43             West Midlands   2179.7094       E06000019
# 44                North East   2232.6115       E06000047
# 45  Yorkshire and the Humber   2495.0970       E06000011
# 46                South West   2521.0750       E06000059
# 47             West Midlands   3197.2758       E06000051
# 48                South West   3255.3380       E06000054
# 49                South West   3612.0597       E06000052
# 50                North East   5077.4757       E06000057
#
#                   Local Authority_y All 'A' roads Total road length   \
# 0                  Middlesbrough UA          48.4              540.5
# 1                     Portsmouth UA          50.8              458.9
# 2                     Nottingham UA          77.9              812.4
# 3                          Derby UA          74.7              779.0
# 4    Kingston upon Hull, City of UA          49.3              775.4
# 5                       Plymouth UA          45.9              839.6
# 6                    North Tyneside          94.9              813.8
# 7              Brighton and Hove UA          60.7              621.7
# 8                 Stoke-on-Trent UA         106.7              882.8
# 9                     Hartlepool UA          48.0              413.6
# 10                         Coventry          60.7              904.1
# 11              Newcastle upon Tyne          89.7              995.9
# 12                       Manchester         118.1            1,391.7
# 13                       Sunderland         107.6            1,174.5
# 14                          Oldham           99.3              828.8
# 15                        Gateshead          77.1              910.7
# 16                         Rochdale          83.1              790.7
# 17                         Solihull          60.2              887.2
# 18                      Thurrock UA          88.0              599.9
# 19                    Darlington UA          65.0              563.2
# 20        Windsor and Maidenhead UA          82.1              684.4
# 21       North East Lincolnshire UA          88.1              660.1
# 22                           Sefton          89.3              995.9
# 23              Stockton-on-Tees UA         104.1              900.3
# 24                       Swindon UA          72.1              942.2
# 25          Redcar and Cleveland UA          95.4              689.4
# 26                          York UA          99.8              816.9
# 27                 Milton Keynes UA          89.0            1,324.2
# 28                         Barnsley         152.8            1,216.2
# 29                        Wakefield         175.0            1,591.4
# 30                  Peterborough UA         124.9              981.4
# 31  Bath and North East Somerset UA         134.4            1,085.2
# 32                       Rutland UA          95.5              557.6
# 33                      Bedford UA          115.5              946.4
# 34         South Gloucestershire UA         127.3            1,611.5
# 35                            Leeds         313.0            3,063.8
# 36                        Doncaster         166.9            1,682.1
# 37                West Berkshire UA         131.1            1,415.1
# 38         Central Bedfordshire UA          167.6            1,585.4
# 39     Cheshire West and Chester UA         320.3            2,449.6
# 40  North Northamptonshire [Note 1]         327.8            2,040.3
# 41   West Northamptonshire [Note 1]         376.8            2,719.8
# 42                 Buckinghamshire          357.7            3,343.8
# 43      Herefordshire, County of UA         450.8            3,353.1
# 44                 County Durham UA         411.5            3,752.8
# 45      East Riding of Yorkshire UA         374.3            3,485.5
# 46                        Dorset UA         436.0            4,096.0
# 47                    Shropshire UA         563.4            5,219.4
# 48                    Wiltshire UA          675.8            4,846.2
# 49                     Cornwall UA          701.2            7,460.0
# 50               Northumberland UA          608.8            5,136.1
#
#     Count Sites
# 0            17
# 1             9
# 2             2
# 3            11
# 4            11
# 5             5
# 6             4
# 7             9
# 8            14
# 9             1
# 10            1
# 11           14
# 12            8
# 13            5
# 14            8
# 15           22
# 16            4
# 17            4
# 18            3
# 19            7
# 20            7
# 21            4
# 22            2
# 23           10
# 24            1
# 25            3
# 26            4
# 27            2
# 28            8
# 29           38
# 30           14
# 31            6
# 32            8
# 33           12
# 34            2
# 35           62
# 36            8
# 37            4
# 38           12
# 39           11
# 40           59
# 41           40
# 42            1
# 43           15
# 44           22
# 45           11
# 46           12
# 47           23
# 48           30
# 49           29
# 50           22

# %%
#REMOVE CORE CITIES HERE
percent_threshold = 0.6
city_types = ["Core City (London)", "Core City (outside London)", "Other City", "Large Town", "Medium Town"]
df_cities = pd.read_csv("./lauth-classification-csv.csv")
df_cities = df_cities.sort_values('percent_of_localauth', ascending=False).drop_duplicates('localauth_code').sort_index()
df_cities = df_cities[(df_cities["percent_of_localauth"] < percent_threshold) | (~df_cities["classification"].isin(city_types)) ]
df_merged_filtered_final = df_merged_final[df_merged_final["Local Authority Code"].isin(list(df_cities["localauth_code"]))]
df_merged_filtered_final.reset_index(inplace=True, drop=True)

df_merged_filtered_final
# Out:
#    Local Authority Code             Local Authority_x  \
# 0             E08000022                North Tyneside
# 1             E08000004                        Oldham
# 2             E08000005                      Rochdale
# 3             E08000029                      Solihull
# 4             E06000034                      Thurrock
# 5             E06000040        Windsor and Maidenhead
# 6             E06000012       North East Lincolnshire
# 7             E08000014                        Sefton
# 8             E06000004              Stockton-on-Tees
# 9             E06000003          Redcar and Cleveland
# 10            E08000016                      Barnsley
# 11            E08000036                     Wakefield
# 12            E06000022  Bath and North East Somerset
# 13            E06000017                       Rutland
# 14            E06000055                       Bedford
# 15            E06000025         South Gloucestershire
# 16            E08000017                     Doncaster
# 17            E06000037                West Berkshire
# 18            E06000056          Central Bedfordshire
# 19            E06000050     Cheshire West and Chester
# 20            E06000019      Herefordshire, County of
# 21            E06000047                 County Durham
# 22            E06000011      East Riding of Yorkshire
# 23            E06000051                    Shropshire
# 24            E06000054                     Wiltshire
# 25            E06000052                      Cornwall
# 26            E06000057                Northumberland
#
#                       Region  Area (km2) ONS Area \nCode  \
# 0                 North East     84.8234       E08000022
# 1                 North West    142.3450       E08000004
# 2                 North West    158.1283       E08000005
# 3              West Midlands    178.2821       E08000029
# 4            East of England    184.3180       E06000034
# 5                 South East    198.4272       E06000040
# 6   Yorkshire and the Humber    202.6626       E06000012
# 7                 North West    202.7557       E08000014
# 8                 North East    209.7309       E06000004
# 9                 North East    253.7857       E06000003
# 10  Yorkshire and the Humber    329.0776       E08000016
# 11  Yorkshire and the Humber    338.6198       E08000036
# 12                South West    351.1235       E06000022
# 13             East Midlands    393.7490       E06000017
# 14           East of England    476.4082       E06000055
# 15                South West    536.4217       E06000025
# 16  Yorkshire and the Humber    568.5513       E08000017
# 17                South East    704.1694       E06000037
# 18           East of England    715.6657       E06000056
# 19                North West    941.2070       E06000050
# 20             West Midlands   2179.7094       E06000019
# 21                North East   2232.6115       E06000047
# 22  Yorkshire and the Humber   2495.0970       E06000011
# 23             West Midlands   3197.2758       E06000051
# 24                South West   3255.3380       E06000054
# 25                South West   3612.0597       E06000052
# 26                North East   5077.4757       E06000057
#
#                   Local Authority_y All 'A' roads Total road length   \
# 0                    North Tyneside          94.9              813.8
# 1                           Oldham           99.3              828.8
# 2                          Rochdale          83.1              790.7
# 3                          Solihull          60.2              887.2
# 4                       Thurrock UA          88.0              599.9
# 5         Windsor and Maidenhead UA          82.1              684.4
# 6        North East Lincolnshire UA          88.1              660.1
# 7                            Sefton          89.3              995.9
# 8               Stockton-on-Tees UA         104.1              900.3
# 9           Redcar and Cleveland UA          95.4              689.4
# 10                         Barnsley         152.8            1,216.2
# 11                        Wakefield         175.0            1,591.4
# 12  Bath and North East Somerset UA         134.4            1,085.2
# 13                       Rutland UA          95.5              557.6
# 14                      Bedford UA          115.5              946.4
# 15         South Gloucestershire UA         127.3            1,611.5
# 16                        Doncaster         166.9            1,682.1
# 17                West Berkshire UA         131.1            1,415.1
# 18         Central Bedfordshire UA          167.6            1,585.4
# 19     Cheshire West and Chester UA         320.3            2,449.6
# 20      Herefordshire, County of UA         450.8            3,353.1
# 21                 County Durham UA         411.5            3,752.8
# 22      East Riding of Yorkshire UA         374.3            3,485.5
# 23                    Shropshire UA         563.4            5,219.4
# 24                    Wiltshire UA          675.8            4,846.2
# 25                     Cornwall UA          701.2            7,460.0
# 26               Northumberland UA          608.8            5,136.1
#
#     Count Sites
# 0             4
# 1             8
# 2             4
# 3             4
# 4             3
# 5             7
# 6             4
# 7             2
# 8            10
# 9             3
# 10            8
# 11           38
# 12            6
# 13            8
# 14           12
# 15            2
# 16            8
# 17            4
# 18           12
# 19           11
# 20           15
# 21           22
# 22           11
# 23           23
# 24           30
# 25           29
# 26           22

# %%
df_sorted_authorities = df_merged_filtered_final.loc[(df_merged_filtered_final["Count Sites"]/(df_merged_filtered_final["All 'A' roads"].astype(float))).sort_values(ascending=False).index]
df_sorted_authorities.drop(columns=["ONS Area \nCode", "Local Authority_y", "Total road length "], inplace=True)
df_sorted_authorities.reset_index(inplace=True, drop=True)
df_sorted_authorities
# Out:
#    Local Authority Code             Local Authority_x  \
# 0             E08000036                     Wakefield
# 1             E06000055                       Bedford
# 2             E06000004              Stockton-on-Tees
# 3             E06000040        Windsor and Maidenhead
# 4             E06000017                       Rutland
# 5             E08000004                        Oldham
# 6             E06000056          Central Bedfordshire
# 7             E08000029                      Solihull
# 8             E06000047                 County Durham
# 9             E08000016                      Barnsley
# 10            E08000005                      Rochdale
# 11            E08000017                     Doncaster
# 12            E06000012       North East Lincolnshire
# 13            E06000022  Bath and North East Somerset
# 14            E06000054                     Wiltshire
# 15            E08000022                North Tyneside
# 16            E06000052                      Cornwall
# 17            E06000051                    Shropshire
# 18            E06000057                Northumberland
# 19            E06000050     Cheshire West and Chester
# 20            E06000034                      Thurrock
# 21            E06000019      Herefordshire, County of
# 22            E06000003          Redcar and Cleveland
# 23            E06000037                West Berkshire
# 24            E06000011      East Riding of Yorkshire
# 25            E08000014                        Sefton
# 26            E06000025         South Gloucestershire
#
#                       Region  Area (km2) All 'A' roads  Count Sites
# 0   Yorkshire and the Humber    338.6198         175.0           38
# 1            East of England    476.4082         115.5           12
# 2                 North East    209.7309         104.1           10
# 3                 South East    198.4272          82.1            7
# 4              East Midlands    393.7490          95.5            8
# 5                 North West    142.3450          99.3            8
# 6            East of England    715.6657         167.6           12
# 7              West Midlands    178.2821          60.2            4
# 8                 North East   2232.6115         411.5           22
# 9   Yorkshire and the Humber    329.0776         152.8            8
# 10                North West    158.1283          83.1            4
# 11  Yorkshire and the Humber    568.5513         166.9            8
# 12  Yorkshire and the Humber    202.6626          88.1            4
# 13                South West    351.1235         134.4            6
# 14                South West   3255.3380         675.8           30
# 15                North East     84.8234          94.9            4
# 16                South West   3612.0597         701.2           29
# 17             West Midlands   3197.2758         563.4           23
# 18                North East   5077.4757         608.8           22
# 19                North West    941.2070         320.3           11
# 20           East of England    184.3180          88.0            3
# 21             West Midlands   2179.7094         450.8           15
# 22                North East    253.7857          95.4            3
# 23                South East    704.1694         131.1            4
# 24  Yorkshire and the Humber   2495.0970         374.3           11
# 25                North West    202.7557          89.3            2
# 26                South West    536.4217         127.3            2

# %%
df_temp = df_sorted_authorities.drop(columns=["Region"])
df_temp.to_latex()
# Out:
# "\\begin{tabular}{lllrlr}\n\\toprule\n & Local Authority Code & Local Authority_x & Area (km2) & All 'A' roads & Count Sites \\\\\n\\midrule\n0 & E08000036 & Wakefield & 338.619800 & 175.0 & 38 \\\\\n1 & E06000055 & Bedford & 476.408200 & 115.5 & 12 \\\\\n2 & E06000004 & Stockton-on-Tees & 209.730900 & 104.1 & 10 \\\\\n3 & E06000040 & Windsor and Maidenhead & 198.427200 & 82.1 & 7 \\\\\n4 & E06000017 & Rutland & 393.749000 & 95.5 & 8 \\\\\n5 & E08000004 & Oldham & 142.345000 & 99.3 & 8 \\\\\n6 & E06000056 & Central Bedfordshire & 715.665700 & 167.6 & 12 \\\\\n7 & E08000029 & Solihull & 178.282100 & 60.2 & 4 \\\\\n8 & E06000047 & County Durham & 2232.611500 & 411.5 & 22 \\\\\n9 & E08000016 & Barnsley & 329.077600 & 152.8 & 8 \\\\\n10 & E08000005 & Rochdale & 158.128300 & 83.1 & 4 \\\\\n11 & E08000017 & Doncaster & 568.551300 & 166.9 & 8 \\\\\n12 & E06000012 & North East Lincolnshire & 202.662600 & 88.1 & 4 \\\\\n13 & E06000022 & Bath and North East Somerset & 351.123500 & 134.4 & 6 \\\\\n14 & E06000054 & Wiltshire & 3255.338000 & 675.8 & 30 \\\\\n15 & E08000022 & North Tyneside & 84.823400 & 94.9 & 4 \\\\\n16 & E06000052 & Cornwall & 3612.059700 & 701.2 & 29 \\\\\n17 & E06000051 & Shropshire & 3197.275800 & 563.4 & 23 \\\\\n18 & E06000057 & Northumberland & 5077.475700 & 608.8 & 22 \\\\\n19 & E06000050 & Cheshire West and Chester & 941.207000 & 320.3 & 11 \\\\\n20 & E06000034 & Thurrock & 184.318000 & 88.0 & 3 \\\\\n21 & E06000019 & Herefordshire, County of & 2179.709400 & 450.8 & 15 \\\\\n22 & E06000003 & Redcar and Cleveland & 253.785700 & 95.4 & 3 \\\\\n23 & E06000037 & West Berkshire & 704.169400 & 131.1 & 4 \\\\\n24 & E06000011 & East Riding of Yorkshire & 2495.097000 & 374.3 & 11 \\\\\n25 & E08000014 & Sefton & 202.755700 & 89.3 & 2 \\\\\n26 & E06000025 & South Gloucestershire & 536.421700 & 127.3 & 2 \\\\\n\\bottomrule\n\\end{tabular}\n"
